# %% [markdown]
# <a href="https://colab.research.google.com/github/KaanErdogdu/6_BootCamp_Lineer_Regresyon/blob/master/5_OLS_Odev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
ev_fiyatlari = pd.read_csv('Ev_Fiyatlari.csv')
ev_fiyatlari.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
ev_fiyatlari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
ev_fiyatlari["Street"] = ev_fiyatlari.Street.replace({'Pave':1, "Grvl":0})
print(ev_fiyatlari["Street"])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1455    1
# 1456    1
# 1457    1
# 1458    1
# 1459    1
# Name: Street, Length: 1460, dtype: int64

# %%
ev_fiyatlari["SaleAge"] = ev_fiyatlari["YrSold"] - ev_fiyatlari['YearBuilt']
ev_fiyatlari["SaleAge"]
# Out:
# 0        5
# 1       31
# 2        7
# 3       91
# 4        8
#         ..
# 1455     8
# 1456    32
# 1457    69
# 1458    60
# 1459    43
# Name: SaleAge, Length: 1460, dtype: int64

# %% [markdown]
# OverallQual
#
# YearBuilt
#
# GrLivArea
#
# GarageArea

# %%
age_ev= ev_fiyatlari.groupby("SaleAge")["SalePrice"].sum()
age_ev
# Out:
# SaleAge
# 0      16915343
# 1      26691400
# 2       8706666
# 3       9113750
# 4       8161600
#          ...
# 127      285500
# 128      295000
# 129      265979
# 135       94000
# 136      122000
# Name: SalePrice, Length: 122, dtype: int64

# %%
Y = ev_fiyatlari['SalePrice']
X = ev_fiyatlari[['OverallQual','YearBuilt','GrLivArea','GarageArea',"SaleAge","Street"]]

# %%
lrm = linear_model.LinearRegression()
lrm.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm.coef_)
print('Sabit değer (bias): \n', lrm.intercept_)
# Out:
# Değişkenler:
#  [23081.55539496   494.58527015    55.67318484    57.8868527
#    113.37688944  6928.35709178]
# Sabit değer (bias):
#  -1057614.1030748312

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     733.8
# Date:                Wed, 01 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:22:23   Log-Likelihood:                -17527.
# No. Observations:                1460   AIC:                         3.507e+04
# Df Residuals:                    1453   BIC:                         3.510e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.058e+06   1.57e+06     -0.672      0.502   -4.15e+06    2.03e+06
# ...

# %%
x=int(input("OverallQual "))
z=int(input("YearBuilt "))
m=int(input("GrLivArea "))
n=int(input("GarageArea "))
t = int(input("SaleAge"))
f = int(input("Street"))
Y = (x*23110.96546475) + (z*381.532147) + (55.70437998*m) + (57.60367344*n)+ (t*113.37688944) + (f*6928.35709178) -823805.2622685758
print(Y)
# Out:
# OverallQual 7
# YearBuilt 2001
# GrLivArea 1800
# GarageArea 600
# SaleAge6
# Street1
# 243856.02858809428

# %%
Y11 = ev_fiyatlari['SalePrice']
X11 = ev_fiyatlari[['OverallQual','GrLivArea','GarageArea']]

# %%
lrm11 = linear_model.LinearRegression()
lrm11.fit(X11, Y11)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm11.coef_)
print('Sabit değer (bias): \n', lrm11.intercept_)
# Out:
# Değişkenler:
#  [27910.78508182    49.64931608    72.94782966]
# Sabit değer (bias):
#  -99060.08677530524

# %%
X11 = sm.add_constant(X11)
results = sm.OLS(Y11, X11).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     1377.
# Date:                Wed, 01 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:25:32   Log-Likelihood:                -17562.
# No. Observations:                1460   AIC:                         3.513e+04
# Df Residuals:                    1456   BIC:                         3.515e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -9.906e+04   4837.368    -20.478      0.000   -1.09e+05   -8.96e+04
# ...

# %% [markdown]
# Varsayım 1: Katsayılarda modelin doğrusallığı

# %%
hava_durumu = pd.read_csv('weatherHistory.csv')
hava_durumu.head(10)
# Out:
#                   Formatted Date  ...                      Daily Summary
# 0  2006-04-01 00:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 1  2006-04-01 01:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 2  2006-04-01 02:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 3  2006-04-01 03:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 4  2006-04-01 04:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 5  2006-04-01 05:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 6  2006-04-01 06:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 7  2006-04-01 07:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 8  2006-04-01 08:00:00.000 +0200  ...  Partly cloudy throughout the day.
# 9  2006-04-01 09:00:00.000 +0200  ...  Partly cloudy throughout the day.
#
# [10 rows x 12 columns]

# %%
hava_durumu["Fark"]=hava_durumu["Apparent Temperature (C)"]-hava_durumu["Temperature (C)"]

# %%
hava_durumu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
#  12  Fark                      96453 non-null  float64
# dtypes: float64(9), object(4)
# ...

# %%
hava_durumu["nemrü"]=hava_durumu["Humidity"] * hava_durumu["Wind Speed (km/h)"]

# %%
hava_durumu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
#  12  Fark                      96453 non-null  float64
# ...

# %%
Y2 = hava_durumu['Fark']
X2 = hava_durumu[['Humidity','Wind Speed (km/h)']]

# %%
lrm_hava = linear_model.LinearRegression()
lrm_hava.fit(X2, Y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm_hava.coef_)
print('Sabit değer (bias): \n', lrm_hava.intercept_)
# Out:
# Değişkenler:
#  [-3.02918594 -0.11929075]
# Sabit değer (bias):
#  2.4381054151877035

# %%
X2 = sm.add_constant(X2)
results = sm.OLS(Y2, X2).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fark   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:52:29   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y3 = hava_durumu['Fark']
X3 = hava_durumu[['Humidity','Wind Speed (km/h)', 'nemrü']]

# %%
lrm_hava2 = linear_model.LinearRegression()
lrm_hava2.fit(X3, Y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm_hava2.coef_)
print('Sabit değer (bias): \n', lrm_hava2.intercept_)
# Out:
# Değişkenler:
#  [ 0.17751219  0.09048213 -0.29711946]
# Sabit değer (bias):
#  0.08393631009782743

# %%
X3 = sm.add_constant(X3)
results = sm.OLS(Y3, X3).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fark   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:54:22   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y4 = hava_durumu['Fark']
X4 = hava_durumu[['Humidity','Wind Speed (km/h)','Visibility (km)']]

# %%
lrm_hava3 = linear_model.LinearRegression()
lrm_hava3.fit(X4, Y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Değişkenler: \n', lrm_hava3.coef_)
print('Sabit değer (bias): \n', lrm_hava3.intercept_)
# Out:
# Değişkenler:
#  [-2.60664109 -0.11990113  0.05398318]
# Sabit değer (bias):
#  1.5755946860023355

# %%
X4 = sm.add_constant(X4)
results = sm.OLS(Y4, X4).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fark   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                 1.401e+04
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:56:57   Log-Likelihood:            -1.6938e+05
# No. Observations:               96453   AIC:                         3.388e+05
# Df Residuals:                   96449   BIC:                         3.388e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
